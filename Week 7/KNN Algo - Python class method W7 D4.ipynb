# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from math import sqrt
from random import randint

# %%
iris_df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X = iris_df.iloc[:, :-1].values
y = iris_df.iloc[:, 4].values

# %%
class KNNClassifier:

    
    def  __init__(self,dataset, predict, num_neighbors):
        self.dataset = np.array(dataset)
        self.predict = predict
        self.num_neighbors = num_neighbors
    
    
    
    @staticmethod       
    def euclidean_distance(self,row1, row2):
        distance = 0.0
        for i in range(len(self.row1)-1):
            distance += (self.row1[i] - self.row2[i])**2
        return sqrt(distance)
    
              
    def get_neighbors(self, train, test_row, num_neighbors):
        distances = list()
        for train_row in self.train:
            dist = self.euclidean_distance(test_row, train_row)
            distances.append((train_row, dist))
        distances.sort(key=lambda tup: tup[1])
        neighbors = list()
        for i in range(num_neighbors):
            neighbors.append(distances[i][0])
            return neighbors
    
    

    def predict_classification(self, num_neighbors):
        neighbors = self.get_neighbors(dataset,self.predict,num_neighbors)
        output_values = [row[-1] for row in neighbors]
        prediction = max(set(output_values), key=output_values.count)
        return prediction


    
X = iris_df[['petal_length', 'petal_width', 'species']]
y = np.array([6.1, 3.2])
target_pred = KNNClassifier(X,y,3)
target_pred.predict_classification(3)
get_neighbors(X, y, 3)

# dataset = [[2.7810836,2.550537003,0],
#         [1.465489372,2.362125076,0],
#         [3.396561688,4.400293529,0],
#         [1.38807019,1.850220317,0],
#         [3.06407232,3.005305973,0],
#         [7.627531214,2.759262235,1],
#         [5.332441248,2.088626775,1],
#         [6.922596716,1.77106367,1],
#         [8.675418651,-0.242068655,1],
#         [7.673756466,3.508563011,1]]


#y_pred.fit(dataset[:8], dataset[-2:])
#euclidean_distance(dataset[3][0], dataset[4][1])
#prediction = predict_classification(dataset, dataset[0], 3)

# euc_dist = euclidean_distance(dataset[3], dataset[4])
# fitted_data = fit(2, dataset[:8], dataset[:-2])
# prediction = predict_classification(dataset, dataset[0], 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-b0bf8ecfdabe> in <module>
#      41 y = np.array([6.1, 3.2])
#      42 target_pred = KNNClassifier(X,y,3)
# ---> 43 target_pred.predict_classification(3)
#      44 get_neighbors(X, y, 3)
#      45
#
# <ipython-input-109-b0bf8ecfdabe> in predict_classification(self, num_neighbors)
#      31
#      32     def predict_classification(self, num_neighbors):
# ---> 33         neighbors = self.get_neighbors(dataset,self.predict,num_neighbors)
#      34         output_values = [row[-1] for row in neighbors]
#      35         prediction = max(set(output_values), key=output_values.count)
#
# <ipython-input-109-b0bf8ecfdabe> in get_neighbors(self, train, test_row, num_neighbors)
#      19     def get_neighbors(self, train, test_row, num_neighbors):
#      20         distances = list()
# ...

# %%
iris_df[['petal_length', 'petal_width', 'species']]
# Out:
#      petal_length  petal_width    species
# 0             1.4          0.2     setosa
# 1             1.4          0.2     setosa
# 2             1.3          0.2     setosa
# 3             1.5          0.2     setosa
# 4             1.4          0.2     setosa
# ..            ...          ...        ...
# 145           5.2          2.3  virginica
# 146           5.0          1.9  virginica
# 147           5.2          2.0  virginica
# 148           5.4          2.3  virginica
# 149           5.1          1.8  virginica
#
# [150 rows x 3 columns]
